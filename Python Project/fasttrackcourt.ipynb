# %% [markdown]
# <a href="https://colab.research.google.com/github/jayeshsc/18CSE301J_RA2011028010094/blob/main/fasttrackcourt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("fasttrackcourt1.csv")
data
ypoints = np.array(data["2020"])
ypoints1 = np.array(data["2021"])
ypoints2 =np.array(data["2022"])
xpoints = np.array(data["State/UT"])

# %%
data.describe
# Out:
# <bound method NDFrame.describe of     S No.           State/UT  2020  2021  2022
# 0        1   Andhra Pradesh      8    10    14
# 1        2             Assam     7    15    17
# 2        3             Bihar    45    45    45
# 3        4        Chandigarh     1     1    48
# 4        5      Chhattisgarh    15    15    15
# 5        6             Delhi     0    16    16
# 6        7           Gujarat    35    35    35
# 7        8               Goa     0     0     1
# 8        9           Haryana    16    16    16
# 9       10          Himachal     3     6     6
# 10      11               J&K     0     4     4
# 11      12         Jharkhand    20    22    22
# 12      13         Karnataka    14    18    30
# 13      14            Kerala    23    28    52
# 14      15  Madhya Pradesh      66    67    67
# 15      16       Maharashtra    25    34    39
# 16      17           Manipur     0     2     2
# 17      18         Meghalaya     0     5     5
# ...

# %%
plt.bar(data["State/UT"],data["2020"], color ='green',width = 0.25)
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
plt.title("State-wise No. of Functional Fast Track Court 2020")
# Out:
# Text(0.5, 1.0, 'State-wise No. of Functional Fast Track Court 2020')

# %%
plt.bar(data["State/UT"],data["2021"], color ='purple',width = 0.25)
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
plt.title("State-wise No. of Functional Fast Track Court 2021")
# Out:
# Text(0.5, 1.0, 'State-wise No. of Functional Fast Track Court 2021')

# %%
plt.bar(data["State/UT"],data["2022"], color ='red',width = 0.25)
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
plt.title("state-wise No. of Functional Fast Track Court 2022")
# Out:
# Text(0.5, 1.0, 'state-wise No. of Functional Fast Track Court 2022')

# %%
plt.plot(ypoints, linestyle = 'dashed',color = 'green')
plt.title("No. of Functional Fast Track Court 2020")
# Out:
# Text(0.5, 1.0, 'No. of Functional Fast Track Court 2020')

# %%
plt.plot(ypoints1, linestyle = 'dashed',color = 'purple')
plt.title("No. of Functional Fast Track Court 2021")
# Out:
# Text(0.5, 1.0, 'No. of Functional Fast Track Court 2021')

# %%
plt.plot(ypoints2, linestyle = 'dashed',color = 'red')
plt.title("No. of Functional Fast Track Court 2022")
# Out:
# Text(0.5, 1.0, 'No. of Functional Fast Track Court 2022')

# %%
plt.plot(xpoints,ypoints,color='green')
plt.title("State-wise No. of Functional Fast Track Court 2020")
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
# Out:
# Text(0, 0.5, 'No. of Functional Court')

# %%
plt.plot(xpoints,ypoints,color='purple')
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
plt.title("State-wise No. of Functional Fast Track Court 2021")
# Out:
# Text(0.5, 1.0, 'State-wise No. of Functional Fast Track Court 2021')

# %%
plt.plot(xpoints,ypoints,color='red')
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
plt.title("State-wise No. of Functional Fast Track Court 2022")
# Out:
# Text(0.5, 1.0, 'State-wise No. of Functional Fast Track Court 2022')

# %%
y = np.array(data["2020"])
plt.pie(y,labels=data["State/UT"])
plt.title("No. of Functional Fast Track Court 2020")
# Out:
# Text(0.5, 1.0, 'No. of Functional Fast Track Court 2020')

# %%
y1 = np.array(data["2021"])
plt.pie(y1,labels=data["State/UT"])
plt.title("No. of Functional Fast Track Court 2021")
# Out:
# Text(0.5, 1.0, 'No. of Functional Fast Track Court 2021')

# %%
y2 = np.array(data["2022"])
plt.pie(y2,labels=data["State/UT"])
plt.title("No. of Functional Fast Track Court 2022")
# Out:
# Text(0.5, 1.0, 'No. of Functional Fast Track Court 2022')

# %%
plt.scatter(xpoints,ypoints,color='green')
plt.title("State-wise No. of Functional Fast Track Court 2020")
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
# Out:
# Text(0, 0.5, 'No. of Functional Court')

# %%
plt.scatter(xpoints,ypoints1,color='purple')
plt.title("State-wise No. of Functional Fast Track Court 2021")
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
# Out:
# Text(0, 0.5, 'No. of Functional Court')

# %%
plt.scatter(xpoints,ypoints2,color='red')
plt.title("State-wise No. of Functional Fast Track Court 2022")
plt.xlabel("State/UT")
plt.ylabel("No. of Functional Court")
# Out:
# Text(0, 0.5, 'No. of Functional Court')

# %%
sns.distplot(ypoints,color='green')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(ypoints1,color='purple')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(ypoints2,color='red')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
